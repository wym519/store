# %%
# !git clone https://github.com/Microsoft/Recommenders

# %%
# !cp -a '/content/Recommenders' '/content/drive/My Drive/newsrec model'

# %%
# !ls
# Out:
# drive  Recommenders  sample_data

# %%
# !cd Recommenders
# !python '/content/drive/My Drive/newsrec model/Recommenders/scripts/generate_conda_file.py'

# %%
# !python
